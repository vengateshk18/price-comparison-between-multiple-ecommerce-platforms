# %% [markdown]
# Importing necessary packages

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.flipkart.com/search?q=iphone14"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
product_info_elements = soup.find_all("div", class_="_4rR01T")
product_price_elements = soup.find_all("div", class_="_30jeq3")

# %%
print(product_info_elements)
# Out:
# [<div class="_4rR01T">APPLE iPhone 14 (Blue, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Purple, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Midnight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Starlight, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Yellow, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Midnight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Blue, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 ((PRODUCT)RED, 128 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Starlight, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Purple, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Yellow, 512 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 ((PRODUCT)RED, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Yellow, 256 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Midnight, 512 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Blue, 512 GB)</div>, <div class="_4rR01T">APPLE iPhone 14 (Starlight, 512 GB)</div>, 
# ...

# %%
product_name_details = []
product_price_details = []

# %%
for product_info_element in product_info_elements:
        product_name = product_info_element.text
        product_name_details.append(product_name)
print(product_name_details)
# Out:
# ['APPLE iPhone 14 (Blue, 128 GB)', 'APPLE iPhone 14 (Purple, 128 GB)', 'APPLE iPhone 14 (Midnight, 128 GB)', 'APPLE iPhone 14 (Starlight, 128 GB)', 'APPLE iPhone 14 (Yellow, 128 GB)', 'APPLE iPhone 14 (Midnight, 256 GB)', 'APPLE iPhone 14 (Blue, 256 GB)', 'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)', 'APPLE iPhone 14 (Starlight, 256 GB)', 'APPLE iPhone 14 (Purple, 256 GB)', 'APPLE iPhone 14 (Yellow, 512 GB)', 'APPLE iPhone 14 ((PRODUCT)RED, 256 GB)', 'APPLE iPhone 14 (Yellow, 256 GB)', 'APPLE iPhone 14 (Midnight, 512 GB)', 'APPLE iPhone 14 (Blue, 512 GB)', 'APPLE iPhone 14 (Starlight, 512 GB)', 'APPLE iPhone 14 ((PRODUCT)RED, 512 GB)', 'APPLE iPhone 14 (Purple, 512 GB)', 'APPLE iPhone 14 Plus (Blue, 128 GB)', 'APPLE iPhone 14 Plus (Starlight, 128 GB)', 'APPLE iPhone 14 Plus (Midnight, 128 GB)', 'APPLE iPhone 14 Plus (Purple, 128 GB)', 'APPLE iPhone 14 Pro (Deep Purple, 128 GB)', 'APPLE iPhone 14 Pro Max (Deep Purple, 128 GB)']

# %%
for product_price_element in product_price_elements:
    product_price = product_price_element.text
    product_price_details.append(product_price)
print(product_price_details)
# Out:
# ['₹64,999', '₹64,999', '₹64,999', '₹64,999', '₹64,999', '₹74,999', '₹74,999', '₹64,999', '₹74,999', '₹74,999', '₹94,999', '₹74,999', '₹74,999', '₹94,999', '₹94,999', '₹94,999', '₹94,999', '₹94,999', '₹73,999', '₹73,999', '₹73,999', '₹73,999', '₹1,19,900', '₹1,27,999']

# %%
#df = pd.DataFrame(product_name_details,product_price_details)
#print(df)

# %%
max_length = max(len(product_name_details),len(product_price_details))
df = pd.DataFrame({'Product_name          ': product_name_details + [None] * (max_length - len(product_name_details)), 'Product_price': product_price_details + [None] * (max_length - len(product_price_details))})
print(df)
# Out:
#                            Product_name           Product_price
# 0                  APPLE iPhone 14 (Blue, 128 GB)       ₹64,999
# 1                APPLE iPhone 14 (Purple, 128 GB)       ₹64,999
# 2              APPLE iPhone 14 (Midnight, 128 GB)       ₹64,999
# 3             APPLE iPhone 14 (Starlight, 128 GB)       ₹64,999
# 4                APPLE iPhone 14 (Yellow, 128 GB)       ₹64,999
# 5              APPLE iPhone 14 (Midnight, 256 GB)       ₹74,999
# 6                  APPLE iPhone 14 (Blue, 256 GB)       ₹74,999
# 7          APPLE iPhone 14 ((PRODUCT)RED, 128 GB)       ₹64,999
# 8             APPLE iPhone 14 (Starlight, 256 GB)       ₹74,999
# 9                APPLE iPhone 14 (Purple, 256 GB)       ₹74,999
# 10               APPLE iPhone 14 (Yellow, 512 GB)       ₹94,999
# 11         APPLE iPhone 14 ((PRODUCT)RED, 256 GB)       ₹74,999
# 12               APPLE iPhone 14 (Yellow, 256 GB)       ₹74,999
# 13             APPLE iPhone 14 (Midnight, 512 GB)       ₹94,999
# ...

# %%
print(len(product_price_details))
print(len(product_name_details))
# Out:
# 24
# 24

# %%
excel_file_path = 'iphone_data.xlsx'

# %%
df.to_excel(excel_file_path, index=False)
